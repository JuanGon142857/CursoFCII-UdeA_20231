# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Leo el archivo .txt con el método read_csv de Pandas
data = pd.read_csv('puntos.txt', header=0, delimiter=',')


# sepato por ejes
x = data['X']
y = data['Y']
z = data['Z']



# Creo una figura y ejes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grafico los datos en los ejes
ax.scatter(x, y, z)
ax.set_xlabel('EJE X')
ax.set_ylabel('EJE Y')
ax.set_zlabel('EJE Z')

# Mostrar la figura
plt.show()
